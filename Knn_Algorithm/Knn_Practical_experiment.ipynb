# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('/content/Social_Network_Ads.csv')
data.head()

# %%
x=data.iloc[:,2:4].values #For input all rows 2 columns

# %%
data.iloc[:,-1]#for output last column

# %%
y=data.iloc[:,-1].values #.values to convert into array

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.20)

# %%
X_train.shape

# %%
X_test.shape

# %% [markdown]
# # Standard Scaling:-
# for changing huge values of Age and EstimatedSalary into small values so that distance formula will be reliable to apply.

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
X_train=scaler.fit_transform(X_train)
X_train

# %%
X_test=scaler.transform(X_test)
X_test

# %% [markdown]
# #Applying KNN on data:-
# first find value of 'K'

# %%
# 1st Method
np.sqrt(X_train.shape[0])

# %%
k=17
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=k)

# %%
knn.fit(X_train,y_train)

# %%
y_pred=knn.predict(X_test)

# %%
y_pred.shape

# %%
y_test.shape

# %%
#Accuracy:
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)

# %%
#Confusion Metrix:
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,y_pred)

# %%
#2nd Method:trial and error method
accuracy=[]
for i in range(1,26):
  knn=KNeighborsClassifier(n_neighbors=i)
  knn.fit(X_train,y_train)
  accuracy.append(accuracy_score(y_test,knn.predict(X_test)))

# %%
len(accuracy)

# %%
plt.plot(range(1,26),accuracy)

# %%
knn=KNeighborsClassifier(n_neighbors=11)
knn.fit(X_train,y_train)

# %%
y_pred=knn.predict(X_test)

# %%
accuracy_score(y_test,y_pred)

# %%
def predict_output():
  age=int(input("Enter the age: "))
  salary=int(input("Enter salary: "))
  X_new= np.array([[age],[salary]]).reshape(1,2)#2D for input
  X_new=scaler.transform(X_new)
  if knn.predict(X_new)[0]==0:
    return "Will not purchase"
  else:
    return "will Purchase"

# %%
predict_output()
